# %% [markdown]
# <a href="https://colab.research.google.com/github/gustavsmnt/Classification-Analysis-using-CNN-and-LSTM-on-Wheezing-Sounds/blob/main/CNN_with_STFT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT LIBRARY JALANKAN PERTAMA

# %%
import numpy as np
import pandas as pd

import os
import librosa

import scipy
from scipy.stats import skew
from tqdm import tqdm, tqdm_pandas

tqdm.pandas()

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

from sklearn.svm import SVC

# %%
# audio_train_files = os.listdir('../input/audio_train')
# audio_test_files = os.listdir('../input/audio_test')

# train = pd.read_csv('../input/train.csv')
# submission = pd.read_csv('../input/sample_submission.csv')

TRAIN_PATH_NORMAL = "/content/drive/MyDrive/dataset/datasetnormal.csv"
TRAIN_PATH_ABNORMAL = "/content/drive/MyDrive/dataset/datasetabnormal.csv"
TRAIN_NORMAL = "/content/drive/MyDrive/dataset/train/normal/"
TRAIN_ABNORMAL = "/content/drive/MyDrive/dataset/train/abnormal/"
TEST = "/content/drive/MyDrive/dataset/test"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_dataset_normal = pd.read_csv(TRAIN_PATH_NORMAL, sep=',')
df_dataset_abnormal = pd.read_csv(TRAIN_PATH_ABNORMAL, sep=',')

# %%
df_dataset_normal
# Out:
#                          fname  labels  labels_count  target_labels_count
# 0   102_1b1_Ar_sc_Meditron.wav  normal             1                    1
# 1   121_1p1_Tc_sc_Meditron.wav  normal             1                    1
# 2   122_2b1_Al_mc_LittC2SE.wav  normal             1                    1
# 3   121_1b1_Tc_sc_Meditron.wav  normal             1                    1
# 4   125_1b1_Tc_sc_Meditron.wav  normal             1                    1
# 5   123_1b1_Al_sc_Meditron.wav  normal             1                    1
# 6   126_1b1_Al_sc_Meditron.wav  normal             1                    1
# 7   127_1b1_Ar_sc_Meditron.wav  normal             1                    1
# 8   136_1b1_Ar_sc_Meditron.wav  normal             1                    1
# 9   143_1b1_Al_sc_Meditron.wav  normal             1                    1
# 10  144_1b1_Al_sc_Meditron.wav  normal             1                    1
# 11  144_1b1_Tc_sc_Meditron.wav  normal             1                    1
# 12  152_1b1_Al_sc_Meditron.wav  normal             1                    1
# 13  153_1b1_Al_sc_Meditron.wav  normal             1                    1
# 14  171_1b1_Al_sc_Meditron.wav  normal             1                    1
# 15  179_1b1_Al_sc_Meditron.wav  normal             1                    1
# 16  179_1b1_Tc_sc_Meditron.wav  normal             1                    1
# 17  182_1b1_Tc_sc_Meditron.wav  normal             1                    1
# 18  183_1b1_Pl_sc_Meditron.wav  normal             1                    1
# 19  183_1b1_Tc_sc_Meditron.wav  normal             1                    1
# 20  184_1b1_Ar_sc_Meditron.wav  normal             1                    1
# 21  187_1b1_Ll_sc_Meditron.wav  normal             1                    1
# 22  194_1b1_Lr_sc_Meditron.wav  normal             1                    1
# 23  194_1b1_Pr_sc_Meditron.wav  normal             1                    1
# 24  202_1b1_Ar_sc_Meditron.wav  normal             1                    1
# 25  208_1b1_Ll_sc_Meditron.wav  normal             1                    1
# 26  209_1b1_Tc_sc_Meditron.wav  normal             1                    1
# 27  214_1b1_Ar_sc_Meditron.wav  normal             1                    1
# 28  217_1b1_Tc_sc_Meditron.wav  normal             1                    1
# 29  224_1b1_Tc_sc_Meditron.wav  normal             1                    1
# 30  224_1b2_Al_sc_Meditron.wav  normal             1                    1
# 31  225_1b1_Pl_sc_Meditron.wav  normal             1                    1

# %%
df_dataset_abnormal
# Out:
#                          fname    labels  labels_count  target_labels_count
# 0   101_1b1_Al_sc_Meditron.wav  abnormal             0                    0
# 1   103_2b2_Ar_mc_LittC2SE.wav  abnormal             0                    0
# 2   104_1b1_Al_sc_Litt3200.wav  abnormal             0                    0
# 3   104_1b1_Ar_sc_Litt3200.wav  abnormal             0                    0
# 4   104_1b1_Ll_sc_Litt3200.wav  abnormal             0                    0
# 5   104_1b1_Lr_sc_Litt3200.wav  abnormal             0                    0
# 6   104_1b1_Pl_sc_Litt3200.wav  abnormal             0                    0
# 7   104_1b1_Pr_sc_Litt3200.wav  abnormal             0                    0
# 8   105_1b1_Tc_sc_Meditron.wav  abnormal             0                    0
# 9   106_2b1_Pl_mc_LittC2SE.wav  abnormal             0                    0
# 10  106_2b1_Pr_mc_LittC2SE.wav  abnormal             0                    0
# 11  108_1b1_Al_sc_Meditron.wav  abnormal             0                    0
# 12  111_1b2_Tc_sc_Meditron.wav  abnormal             0                    0
# 13  111_1b3_Tc_sc_Meditron.wav  abnormal             0                    0
# 14  115_1b1_Ar_sc_Meditron.wav  abnormal             0                    0
# 15  116_1b2_Tc_sc_Meditron.wav  abnormal             0                    0
# 16  135_2b1_Al_mc_LittC2SE.wav  abnormal             0                    0
# 17  135_2b1_Ar_mc_LittC2SE.wav  abnormal             0                    0
# 18  135_2b1_Pl_mc_LittC2SE.wav  abnormal             0                    0
# 19  135_2b1_Tc_mc_LittC2SE.wav  abnormal             0                    0
# 20  135_2b2_Al_mc_LittC2SE.wav  abnormal             0                    0
# 21  135_2b2_Ar_mc_LittC2SE.wav  abnormal             0                    0
# 22  135_2b2_Pl_mc_LittC2SE.wav  abnormal             0                    0
# 23  135_2b2_Tc_mc_LittC2SE.wav  abnormal             0                    0
# 24  135_2b3_Al_mc_LittC2SE.wav  abnormal             0                    0
# 25  135_2b3_Ar_mc_LittC2SE.wav  abnormal             0                    0
# 26  135_2b3_Pl_mc_LittC2SE.wav  abnormal             0                    0
# 27  135_2b3_Pr_mc_LittC2SE.wav  abnormal             0                    0
# 28  135_2b3_Tc_mc_LittC2SE.wav  abnormal             0                    0
# 29  140_2b2_Ll_mc_LittC2SE.wav  abnormal             0                    0
# 30  140_2b2_Tc_mc_LittC2SE.wav  abnormal             0                    0
# 31  140_2b3_Ll_mc_LittC2SE.wav  abnormal             0                    0
# 32  140_2b3_Tc_mc_LittC2SE.wav  abnormal             0                    0

# %%
#FITUR EKSTRAKSI JALANKAN KEDUA

# %%
import librosa
import os
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
import numpy as np
from tqdm import tqdm

# %%
SAMPLING_RATE = 44100
STFT_NUM = 1025
STFT_MAX_LEN = 20

target_labels = ['normal', 'abnormal']

# %%
def wav2stft(wave):
#     mfcc = librosa.feature.mfcc(wave, sr=16000)
    stft = librosa.stft(wave, n_fft=2048, hop_length=64)
    max_len = STFT_MAX_LEN

    # If maximum length exceeds mfcc lengths then pad the remaining ones
    if (max_len > stft.shape[1]):
        pad_width = max_len - stft.shape[1]
        stft = np.pad(stft, pad_width=((0, 0), (0, pad_width)), mode='constant')

    # Else cutoff the remaining parts
    else:
        stft = stft[:, :max_len]
    
    return stft

# %%
def get_label_num(labels):
    lbs = labels.split(",")
#     target_lb = "Accelerating_and_revving_and_vroom"
    target_arr = np.zeros(2)
    for lb in lbs:
        if(lb in target_labels):
            i = target_labels.index(lb)
            target_arr[i] = 1
            break
    return target_arr

# %%
X = []
y = []

def append_X_Y(labels, wave):
    y.append(get_label_num(labels))
    stft = wav2stft(wave)
    X.append(stft)

for index, row in tqdm(df_dataset_normal.iterrows()):
    labels = row["labels"]
    wave, sr = librosa.load(TRAIN_NORMAL + row["fname"], mono=True, sr=44100)
    wave = wave[::3]

    append_X_Y(labels, wave)

for index, row in tqdm(df_dataset_abnormal.iterrows()):
    labels = row["labels"]
    wave, sr = librosa.load(TRAIN_ABNORMAL + row["fname"], mono=True, sr=44100)
    wave = wave[::3]

    append_X_Y(labels, wave)
# Out:
# 32it [00:04,  6.88it/s]
# 33it [00:10,  3.18it/s]

# %%
X = np.array(X)
y = np.array(y)
X.shape[0] == len(y)
# Out:
# True

# %%
X.shape
# Out:
# (65, 1025, 20)

# %%
X[0].shape
# Out:
# (1025, 20)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.2, random_state=True)

# %%
X_test
# Out:
# array([[[ 4.99611740e+01+0.00000000e+00j,
#           4.96160049e+01+0.00000000e+00j,
#           4.85994148e+01+0.00000000e+00j, ...,
#           1.16645393e+01+0.00000000e+00j,
#           1.04071264e+01+0.00000000e+00j,
#           9.44109631e+00+0.00000000e+00j],
#         [-3.48229828e+01-4.82253126e-16j,
#          -3.44122963e+01-3.83393741e+00j,
#          -3.31979446e+01-7.48192072e+00j, ...,
#          -6.18190527e+00-7.94850826e-01j,
#          -7.05751419e+00-1.24836719e+00j,
#          -7.36514616e+00-2.15658116e+00j],
#         [ 3.76897752e-01-1.83962533e-16j,
#           1.81361234e+00-3.32608294e+00j,
#           5.56892490e+00-4.88382530e+00j, ...,
#           7.21524525e+00-5.24202442e+00j,
#           8.19467640e+00-1.05934238e+00j,
#           7.36628056e+00+2.69355178e+00j],
#         ...,
#         [-5.55045437e-03+1.00262119e-16j,
#          -5.03945630e-03+2.27997033e-03j,
#          -3.64108966e-03+4.11985582e-03j, ...,
#          -5.53387310e-03-1.54115621e-03j,
#          -5.92786539e-03+8.09719786e-04j,
#          -5.20535884e-03+3.27092409e-03j],
#         [ 2.51485757e-03-5.89805982e-17j,
#           2.34280480e-03-8.88713927e-04j,
#           1.82584964e-03-1.64225698e-03j, ...,
#           5.10038156e-03+1.12888520e-03j,
#           4.94015170e-03+5.33937164e-05j,
#           4.45251307e-03-8.22066213e-04j],
#         [-3.88444372e-04+0.00000000e+00j,
#          -3.83809849e-04+0.00000000e+00j,
#          -3.97052761e-04+0.00000000e+00j, ...,
#          -4.42356477e-03+0.00000000e+00j,
#          -4.81138285e-03+0.00000000e+00j,
#          -5.13969595e-03+0.00000000e+00j]],
#
#        [[ 7.24506760e+01+0.00000000e+00j,
#           7.13503494e+01+0.00000000e+00j,
#           6.80961304e+01+0.00000000e+00j, ...,
#           1.38047591e-01+0.00000000e+00j,
#           6.09145403e+00+0.00000000e+00j,
#           1.22377853e+01+0.00000000e+00j],
#         [-8.48118210e+01-1.31145095e-15j,
#          -8.21925812e+01-1.88079338e+01j,
#          -7.46039963e+01-3.60230179e+01j, ...,
#           9.29132938e+00+3.95894089e+01j,
#          -8.40704978e-01+4.18645287e+01j,
#          -1.11192665e+01+4.13150330e+01j],
#         [ 5.70051918e+01+3.52693058e-16j,
#           5.53612747e+01+1.44493332e+01j,
#           5.02619476e+01+2.85210419e+01j, ...,
#          -5.86682606e+00-1.42578220e+01j,
#          -7.30056334e+00-1.58892393e+01j,
#          -6.91059208e+00-2.07704124e+01j],
#         ...,
#         [ 3.15701519e-03-5.19226538e-16j,
#           3.10864393e-03-5.97739592e-04j,
#           2.96775624e-03-1.19803997e-03j, ...,
#          -2.86119152e-03+2.00246670e-03j,
#          -2.39205104e-03+2.39868346e-03j,
#          -2.03471491e-03+2.81675137e-03j],
#         [-3.54714273e-03-4.09394740e-16j,
#          -3.41933710e-03+1.25187333e-03j,
#          -3.03147733e-03+2.44678068e-03j, ...,
#           7.53845833e-03-3.14882887e-03j,
#           6.70763757e-03-4.29374538e-03j,
#           5.53458650e-03-5.17594954e-03j],
#         [ 6.75654737e-04+0.00000000e+00j,
#           5.56793180e-04+0.00000000e+00j,
#           2.15620879e-04+0.00000000e+00j, ...,
#          -8.78491532e-03+0.00000000e+00j,
#          -8.14781245e-03+0.00000000e+00j,
#          -7.45087350e-03+0.00000000e+00j]],
#
#        [[ 2.72678955e+02+0.00000000e+00j,
#           2.71321716e+02+0.00000000e+00j,
#           2.67179138e+02+0.00000000e+00j, ...,
#          -8.10889893e+01+0.00000000e+00j,
#          -9.33388367e+01+0.00000000e+00j,
#          -9.97173615e+01+0.00000000e+00j],
#         [-1.56390030e+02-9.43689571e-16j,
#          -1.56195114e+02-7.93665123e+00j,
#          -1.55605881e+02-1.62593670e+01j, ...,
#           1.25017906e+02-1.18695961e+02j,
#           1.52284958e+02-8.11749802e+01j,
#           1.69231369e+02-3.67151184e+01j],
#         [-4.05623817e+00-3.29681303e-17j,
#          -9.21518445e-01-9.70366096e+00j,
#           7.54064274e+00-1.62897377e+01j, ...,
#          -5.89388847e+01+1.44945282e+02j,
#          -1.14288414e+02+1.31497665e+02j,
#          -1.64731567e+02+9.32412796e+01j],
#         ...,
#         [ 3.40909814e-03+2.75829424e-16j,
#           3.19929910e-03-1.12022553e-03j,
#           2.60119792e-03-2.07644445e-03j, ...,
#           4.46816091e-04-6.04436500e-04j,
#           3.96311663e-07-8.51355784e-04j,
#          -5.05965203e-04-8.47933348e-04j],
#         [-3.25152557e-03+1.11022302e-16j,
#          -3.12730460e-03+8.46661103e-04j,
#          -2.77213752e-03+1.61576795e-03j, ...,
#           1.28887058e-03-3.33287928e-04j,
#           1.28290849e-03-4.42420831e-04j,
#           1.28956279e-03-5.87600865e-04j],
#         [ 2.12145224e-03+0.00000000e+00j,
#           2.07810570e-03+0.00000000e+00j,
#           1.94605684e-03+0.00000000e+00j, ...,
#          -2.07958766e-03+0.00000000e+00j,
#          -1.93409645e-03+0.00000000e+00j,
#          -1.72663294e-03+0.00000000e+00j]],
#
#        ...,
#
#        [[ 2.96849079e+01+0.00000000e+00j,
#           2.95165653e+01+0.00000000e+00j,
#           2.89446087e+01+0.00000000e+00j, ...,
#           1.48367290e+01+0.00000000e+00j,
#           1.56886978e+01+0.00000000e+00j,
#           1.65414143e+01+0.00000000e+00j],
#         [-3.32482376e+01-2.18575158e-16j,
#          -3.20124435e+01-7.07547617e+00j,
#          -2.85456982e+01-1.32847595e+01j, ...,
#          -1.49597006e+01+3.57063794e+00j,
#          -1.49321184e+01+6.57883823e-01j,
#          -1.38247538e+01-1.85397756e+00j],
#         [ 2.13994598e+01+1.11022302e-16j,
#           2.10386143e+01+5.46207905e+00j,
#           1.95914936e+01+1.12898254e+01j, ...,
#           2.23355331e+01+5.77035904e+00j,
#           1.62503777e+01+1.44137897e+01j,
#           7.30847788e+00+1.89255371e+01j],
#         ...,
#         [-2.15474756e-06+0.00000000e+00j,
#          -1.97603413e-06+8.21033211e-07j,
#          -1.46684204e-06+1.47707181e-06j, ...,
#           2.61180986e-07+2.16806484e-08j,
#           2.22031915e-07-1.41586156e-07j,
#           8.97269814e-08-2.64630359e-07j],
#         [ 2.51713755e-06-7.28583860e-17j,
#           2.44991088e-06-4.15219347e-07j,
#           2.27060764e-06-7.88816067e-07j, ...,
#           2.10438870e-07-1.67760277e-07j,
#           2.07205659e-07-1.83971338e-07j,
#           1.97969428e-07-2.11197559e-07j],
#         [-2.86753493e-06+0.00000000e+00j,
#          -2.85249507e-06+0.00000000e+00j,
#          -2.79337769e-06+0.00000000e+00j, ...,
#          -3.67225226e-07+0.00000000e+00j,
#          -3.01763464e-07+0.00000000e+00j,
#          -2.33706572e-07+0.00000000e+00j]],
#
#        [[ 6.65638447e+00+0.00000000e+00j,
#           6.67774677e+00+0.00000000e+00j,
#           6.73963404e+00+0.00000000e+00j, ...,
#           8.42900276e+00+0.00000000e+00j,
#           8.45891380e+00+0.00000000e+00j,
#           8.48962116e+00+0.00000000e+00j],
#         [-1.76856947e+00-1.79977561e-17j,
#          -1.86633909e+00+6.01022124e-01j,
#          -2.14854431e+00+1.13494933e+00j, ...,
#          -3.28816533e+00-4.40080762e-02j,
#          -3.31308532e+00+3.22597116e-01j,
#          -3.47673249e+00+6.57506287e-01j],
#         [-2.35781574e+00-2.89078018e-17j,
#          -2.22897315e+00-7.62456298e-01j,
#          -1.85570657e+00-1.44283950e+00j, ...,
#          -1.66995025e+00+2.98136532e-01j,
#          -1.68479431e+00-3.34489107e-01j,
#          -1.46974981e+00-9.39890146e-01j],
#         ...,
#         [-1.73278158e-06-7.52139036e-18j,
#          -1.58093610e-06+6.67145173e-07j,
#          -1.16211015e-06+1.19366200e-06j, ...,
#           5.32938813e-08+5.68271084e-08j,
#           7.11608621e-08+3.09003738e-08j,
#           7.69120447e-08+2.35873376e-10j],
#         [ 1.69340865e-06+2.38524478e-18j,
#           1.64513324e-06-3.23474296e-07j,
#           1.50598623e-06-6.15952729e-07j, ...,
#          -1.51099080e-08-2.70376130e-08j,
#          -2.34425475e-08-1.57853943e-08j,
#          -2.69683049e-08-2.20994911e-09j],
#         [-1.71236991e-06+0.00000000e+00j,
#          -1.69661178e-06+0.00000000e+00j,
#          -1.64981066e-06+0.00000000e+00j, ...,
#          -1.80534805e-08+0.00000000e+00j,
#          -1.78726385e-08+0.00000000e+00j,
#          -1.78224457e-08+0.00000000e+00j]],
#
#        [[-2.36021530e+02+0.00000000e+00j,
#          -2.34606003e+02+0.00000000e+00j,
#          -2.30333679e+02+0.00000000e+00j, ...,
#           3.01513805e+01+0.00000000e+00j,
#           4.53012047e+01+0.00000000e+00j,
#           5.93954353e+01+0.00000000e+00j],
#         [ 1.50860870e+02+1.92901251e-15j,
#           1.49748718e+02+1.28468199e+01j,
#           1.46499023e+02+2.53892822e+01j, ...,
#          -4.47984352e+01+5.97551498e+01j,
#          -5.08433762e+01+4.82891464e+01j,
#          -5.36316872e+01+3.79724236e+01j],
#         [-3.40860252e+01-4.79974184e-16j,
#          -3.31047592e+01-7.03780270e+00j,
#          -3.03185291e+01-1.32548370e+01j, ...,
#           4.90357399e+01-2.29112320e+01j,
#           5.11562576e+01-4.50251055e+00j,
#           4.54793205e+01+1.40319443e+01j],
#         ...,
#         [-6.76632626e-04-1.02892884e-16j,
#          -5.78530191e-04+3.69253481e-04j,
#          -3.06695234e-04+6.40847778e-04j, ...,
#           7.22658762e-04-4.94531632e-05j,
#           6.53274066e-04-4.39567695e-04j,
#           3.99392855e-04-7.35039182e-04j],
#         [-5.69395197e-04-4.16333634e-17j,
#          -5.82538778e-04-9.95087885e-06j,
#          -6.15179306e-04-6.43386193e-06j, ...,
#           1.13724906e-04+6.02111977e-04j,
#           1.90502542e-04+6.27575500e-04j,
#           2.89516698e-04+6.49675610e-04j],
#         [ 1.20232231e-03+0.00000000e+00j,
#           1.19137182e-03+0.00000000e+00j,
#           1.16255844e-03+0.00000000e+00j, ...,
#          -3.47343506e-04+0.00000000e+00j,
#          -5.11940627e-04+0.00000000e+00j,
#          -6.64007035e-04+0.00000000e+00j]]], dtype=complex64)

# %%
#MODEL CNN JALANKAN KETIGA

# %%
# Feature dimension
feature_dim_1 = STFT_NUM
# Second dimension of the feature is dim2
feature_dim_2 = STFT_MAX_LEN
channel = 1
epochs = 150
batch_size = 2
verbose = 1
num_classes = len(target_labels)

# %%
X_train = X_train.reshape(X_train.shape[0], feature_dim_1, feature_dim_2, channel)
X_test = X_test.reshape(X_test.shape[0], feature_dim_1, feature_dim_2, channel)

y_train_hot = y_train
y_test_hot = y_test

# %%
import keras
import tensorflow
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.utils import to_categorical
from keras import optimizers

# %%
def get_model():
    model = Sequential()
    model.add(Conv2D(32, kernel_size=(2, 2), activation='relu', input_shape=(feature_dim_1, feature_dim_2, channel)))
    model.add(Conv2D(48, kernel_size=(2, 2), activation='relu'))
    model.add(Conv2D(120, kernel_size=(2, 2), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.25))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.4))
    model.add(Dense(num_classes, activation='softmax'))
    return model

# %%
model = get_model()

optimizer = tensorflow.keras.optimizers.SGD(lr=0.001, decay=1e-2, momentum=0.9, nesterov=True)
# optimizer = optimizers.Adagrad(lr=0.01, epsilon=None, decay=0.0)
model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=optimizer,
              metrics=['accuracy'])
model.fit(X_train, y_train_hot, epochs=epochs, verbose=verbose, validation_data=(X_test, y_test_hot))
# Out:
# Epoch 1/150
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# 2/2 [==============================] - 7s 3s/step - loss: 0.6839 - accuracy: 0.5192 - val_loss: 0.6348 - val_accuracy: 0.6154
# Epoch 2/150
# 2/2 [==============================] - 8s 4s/step - loss: 0.6531 - accuracy: 0.5769 - val_loss: 0.5971 - val_accuracy: 0.5385
# Epoch 3/150
# 2/2 [==============================] - 8s 3s/step - loss: 0.6678 - accuracy: 0.5385 - val_loss: 0.6072 - val_accuracy: 0.5385
# Epoch 4/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.8345 - accuracy: 0.5577 - val_loss: 0.5544 - val_accuracy: 0.5385
# Epoch 5/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.6209 - accuracy: 0.6154 - val_loss: 0.7273 - val_accuracy: 0.4615
# Epoch 6/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.6469 - accuracy: 0.5577 - val_loss: 0.7589 - val_accuracy: 0.4615
# Epoch 7/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.5443 - accuracy: 0.6731 - val_loss: 0.7244 - val_accuracy: 0.4615
# Epoch 8/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.5744 - accuracy: 0.7692 - val_loss: 0.7113 - val_accuracy: 0.5385
# Epoch 9/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.5343 - accuracy: 0.5962 - val_loss: 0.7153 - val_accuracy: 0.5385
# Epoch 10/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.5350 - accuracy: 0.7115 - val_loss: 0.7336 - val_accuracy: 0.4615
# Epoch 11/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.5276 - accuracy: 0.6731 - val_loss: 0.7201 - val_accuracy: 0.5385
# Epoch 12/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.5319 - accuracy: 0.6731 - val_loss: 0.7010 - val_accuracy: 0.5385
# Epoch 13/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.4409 - accuracy: 0.7692 - val_loss: 0.7540 - val_accuracy: 0.5385
# Epoch 14/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.4807 - accuracy: 0.7885 - val_loss: 0.7875 - val_accuracy: 0.4615
# Epoch 15/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.5504 - accuracy: 0.6923 - val_loss: 0.8005 - val_accuracy: 0.4615
# Epoch 16/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.4743 - accuracy: 0.7692 - val_loss: 0.7735 - val_accuracy: 0.5385
# Epoch 17/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.4414 - accuracy: 0.7500 - val_loss: 0.7139 - val_accuracy: 0.5385
# Epoch 18/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.4264 - accuracy: 0.7115 - val_loss: 0.7080 - val_accuracy: 0.5385
# Epoch 19/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.4088 - accuracy: 0.8269 - val_loss: 0.6932 - val_accuracy: 0.6154
# Epoch 20/150
# 2/2 [==============================] - 7s 3s/step - loss: 0.4570 - accuracy: 0.7500 - val_loss: 0.7631 - val_accuracy: 0.5385
# Epoch 21/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.4028 - accuracy: 0.8269 - val_loss: 0.8053 - val_accuracy: 0.4615
# Epoch 22/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.4073 - accuracy: 0.7885 - val_loss: 0.8050 - val_accuracy: 0.5385
# Epoch 23/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.3662 - accuracy: 0.8654 - val_loss: 0.7877 - val_accuracy: 0.5385
# Epoch 24/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.3493 - accuracy: 0.8654 - val_loss: 0.7327 - val_accuracy: 0.5385
# Epoch 25/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.3794 - accuracy: 0.8654 - val_loss: 0.6957 - val_accuracy: 0.6923
# Epoch 26/150
# 2/2 [==============================] - 7s 3s/step - loss: 0.3590 - accuracy: 0.8269 - val_loss: 0.7004 - val_accuracy: 0.6154
# Epoch 27/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.3343 - accuracy: 0.8654 - val_loss: 0.7420 - val_accuracy: 0.5385
# Epoch 28/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.4027 - accuracy: 0.7692 - val_loss: 0.8132 - val_accuracy: 0.5385
# Epoch 29/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.3398 - accuracy: 0.8846 - val_loss: 0.8596 - val_accuracy: 0.5385
# Epoch 30/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.3395 - accuracy: 0.8462 - val_loss: 0.8712 - val_accuracy: 0.4615
# Epoch 31/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.3178 - accuracy: 0.8654 - val_loss: 0.8475 - val_accuracy: 0.4615
# Epoch 32/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.2542 - accuracy: 0.9231 - val_loss: 0.8513 - val_accuracy: 0.4615
# Epoch 33/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.2979 - accuracy: 0.8846 - val_loss: 0.8365 - val_accuracy: 0.5385
# Epoch 34/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.4088 - accuracy: 0.8462 - val_loss: 0.7766 - val_accuracy: 0.5385
# Epoch 35/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.3722 - accuracy: 0.8654 - val_loss: 0.6862 - val_accuracy: 0.6154
# Epoch 36/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.3184 - accuracy: 0.8462 - val_loss: 0.6817 - val_accuracy: 0.6154
# Epoch 37/150
# 2/2 [==============================] - 7s 3s/step - loss: 0.3006 - accuracy: 0.8462 - val_loss: 0.7330 - val_accuracy: 0.6154
# Epoch 38/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.2975 - accuracy: 0.9231 - val_loss: 0.7456 - val_accuracy: 0.6154
# Epoch 39/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.3100 - accuracy: 0.8846 - val_loss: 0.7744 - val_accuracy: 0.4615
# Epoch 40/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.3478 - accuracy: 0.8462 - val_loss: 0.8218 - val_accuracy: 0.4615
# Epoch 41/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.2914 - accuracy: 0.8654 - val_loss: 0.8461 - val_accuracy: 0.4615
# Epoch 42/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.2918 - accuracy: 0.8846 - val_loss: 0.8673 - val_accuracy: 0.4615
# Epoch 43/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.2903 - accuracy: 0.8654 - val_loss: 0.8718 - val_accuracy: 0.4615
# Epoch 44/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.3340 - accuracy: 0.8462 - val_loss: 0.7666 - val_accuracy: 0.3846
# Epoch 45/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.2898 - accuracy: 0.8654 - val_loss: 0.7282 - val_accuracy: 0.4615
# Epoch 46/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.2635 - accuracy: 0.8846 - val_loss: 0.7640 - val_accuracy: 0.4615
# Epoch 47/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.2798 - accuracy: 0.8462 - val_loss: 0.7803 - val_accuracy: 0.4615
# Epoch 48/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.2791 - accuracy: 0.8846 - val_loss: 0.8605 - val_accuracy: 0.4615
# Epoch 49/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.2427 - accuracy: 0.8654 - val_loss: 0.8772 - val_accuracy: 0.4615
# Epoch 50/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.2576 - accuracy: 0.9423 - val_loss: 0.9093 - val_accuracy: 0.4615
# Epoch 51/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.2549 - accuracy: 0.9423 - val_loss: 0.9605 - val_accuracy: 0.4615
# Epoch 52/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.2999 - accuracy: 0.9038 - val_loss: 0.8024 - val_accuracy: 0.3846
# Epoch 53/150
# 2/2 [==============================] - 7s 3s/step - loss: 0.2173 - accuracy: 0.9423 - val_loss: 0.6958 - val_accuracy: 0.5385
# Epoch 54/150
# 2/2 [==============================] - 10s 3s/step - loss: 0.2403 - accuracy: 0.9231 - val_loss: 0.6321 - val_accuracy: 0.5385
# Epoch 55/150
# 2/2 [==============================] - 7s 3s/step - loss: 0.3187 - accuracy: 0.8269 - val_loss: 0.6689 - val_accuracy: 0.5385
# Epoch 56/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.2468 - accuracy: 0.9231 - val_loss: 0.7195 - val_accuracy: 0.3846
# Epoch 57/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.2445 - accuracy: 0.9423 - val_loss: 0.7933 - val_accuracy: 0.4615
# Epoch 58/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.2483 - accuracy: 0.9038 - val_loss: 0.8129 - val_accuracy: 0.4615
# Epoch 59/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.2364 - accuracy: 0.9038 - val_loss: 0.8189 - val_accuracy: 0.4615
# Epoch 60/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.2553 - accuracy: 0.9038 - val_loss: 0.8599 - val_accuracy: 0.4615
# Epoch 61/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.2550 - accuracy: 0.9038 - val_loss: 0.8613 - val_accuracy: 0.4615
# Epoch 62/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.2380 - accuracy: 0.9231 - val_loss: 0.8429 - val_accuracy: 0.4615
# Epoch 63/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.2064 - accuracy: 0.9231 - val_loss: 0.8384 - val_accuracy: 0.4615
# Epoch 64/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1949 - accuracy: 0.9615 - val_loss: 0.8667 - val_accuracy: 0.4615
# Epoch 65/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.2266 - accuracy: 0.9423 - val_loss: 0.8428 - val_accuracy: 0.4615
# Epoch 66/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1933 - accuracy: 0.9615 - val_loss: 0.8253 - val_accuracy: 0.4615
# Epoch 67/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.2148 - accuracy: 0.9038 - val_loss: 0.8396 - val_accuracy: 0.4615
# Epoch 68/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.2204 - accuracy: 0.9423 - val_loss: 0.8451 - val_accuracy: 0.4615
# Epoch 69/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.2181 - accuracy: 0.9038 - val_loss: 0.8375 - val_accuracy: 0.4615
# Epoch 70/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.2180 - accuracy: 0.9423 - val_loss: 0.8257 - val_accuracy: 0.4615
# Epoch 71/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1732 - accuracy: 0.9615 - val_loss: 0.8276 - val_accuracy: 0.4615
# Epoch 72/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.2267 - accuracy: 0.9038 - val_loss: 0.8789 - val_accuracy: 0.4615
# Epoch 73/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1857 - accuracy: 0.9231 - val_loss: 0.8594 - val_accuracy: 0.4615
# Epoch 74/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1835 - accuracy: 0.9423 - val_loss: 0.8502 - val_accuracy: 0.4615
# Epoch 75/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.2149 - accuracy: 0.9423 - val_loss: 0.7741 - val_accuracy: 0.4615
# Epoch 76/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1690 - accuracy: 0.9808 - val_loss: 0.7273 - val_accuracy: 0.3846
# Epoch 77/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.2120 - accuracy: 0.9423 - val_loss: 0.7231 - val_accuracy: 0.3846
# Epoch 78/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1656 - accuracy: 0.9615 - val_loss: 0.7409 - val_accuracy: 0.3846
# Epoch 79/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1646 - accuracy: 0.9808 - val_loss: 0.7829 - val_accuracy: 0.3846
# Epoch 80/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1959 - accuracy: 0.9231 - val_loss: 0.8419 - val_accuracy: 0.4615
# Epoch 81/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1680 - accuracy: 0.9808 - val_loss: 0.8971 - val_accuracy: 0.4615
# Epoch 82/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1903 - accuracy: 0.9423 - val_loss: 0.8789 - val_accuracy: 0.4615
# Epoch 83/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.2060 - accuracy: 0.9038 - val_loss: 0.8570 - val_accuracy: 0.4615
# Epoch 84/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1884 - accuracy: 0.9423 - val_loss: 0.8135 - val_accuracy: 0.4615
# Epoch 85/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.2102 - accuracy: 0.9423 - val_loss: 0.8391 - val_accuracy: 0.4615
# Epoch 86/150
# 2/2 [==============================] - 7s 3s/step - loss: 0.1717 - accuracy: 0.9231 - val_loss: 0.8735 - val_accuracy: 0.4615
# Epoch 87/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1797 - accuracy: 0.9423 - val_loss: 0.9310 - val_accuracy: 0.4615
# Epoch 88/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1622 - accuracy: 0.9231 - val_loss: 0.9527 - val_accuracy: 0.4615
# Epoch 89/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1685 - accuracy: 0.9615 - val_loss: 0.9806 - val_accuracy: 0.4615
# Epoch 90/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1616 - accuracy: 0.9423 - val_loss: 0.9643 - val_accuracy: 0.4615
# Epoch 91/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1938 - accuracy: 0.9231 - val_loss: 0.9114 - val_accuracy: 0.4615
# Epoch 92/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1493 - accuracy: 0.9615 - val_loss: 0.8597 - val_accuracy: 0.4615
# Epoch 93/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1667 - accuracy: 0.9231 - val_loss: 0.8183 - val_accuracy: 0.4615
# Epoch 94/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.2007 - accuracy: 0.9038 - val_loss: 0.7909 - val_accuracy: 0.4615
# Epoch 95/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1859 - accuracy: 0.9808 - val_loss: 0.7914 - val_accuracy: 0.4615
# Epoch 96/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.2061 - accuracy: 0.9423 - val_loss: 0.8020 - val_accuracy: 0.4615
# Epoch 97/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1562 - accuracy: 0.9808 - val_loss: 0.8202 - val_accuracy: 0.4615
# Epoch 98/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1385 - accuracy: 0.9808 - val_loss: 0.8933 - val_accuracy: 0.4615
# Epoch 99/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1850 - accuracy: 0.9231 - val_loss: 0.9526 - val_accuracy: 0.4615
# Epoch 100/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1357 - accuracy: 0.9423 - val_loss: 1.0121 - val_accuracy: 0.4615
# Epoch 101/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1896 - accuracy: 0.9423 - val_loss: 0.9705 - val_accuracy: 0.4615
# Epoch 102/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1711 - accuracy: 0.9423 - val_loss: 0.8563 - val_accuracy: 0.4615
# Epoch 103/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1705 - accuracy: 0.9615 - val_loss: 0.7645 - val_accuracy: 0.3846
# Epoch 104/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1459 - accuracy: 0.9808 - val_loss: 0.7336 - val_accuracy: 0.3846
# Epoch 105/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1708 - accuracy: 0.9423 - val_loss: 0.7129 - val_accuracy: 0.4615
# Epoch 106/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1391 - accuracy: 0.9808 - val_loss: 0.7214 - val_accuracy: 0.4615
# Epoch 107/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1511 - accuracy: 0.9808 - val_loss: 0.7411 - val_accuracy: 0.3846
# Epoch 108/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1546 - accuracy: 0.9423 - val_loss: 0.7493 - val_accuracy: 0.3846
# Epoch 109/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1525 - accuracy: 0.9808 - val_loss: 0.7610 - val_accuracy: 0.4615
# Epoch 110/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1707 - accuracy: 0.9423 - val_loss: 0.7580 - val_accuracy: 0.4615
# Epoch 111/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1546 - accuracy: 0.9615 - val_loss: 0.7651 - val_accuracy: 0.4615
# Epoch 112/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1602 - accuracy: 0.9615 - val_loss: 0.8131 - val_accuracy: 0.4615
# Epoch 113/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1329 - accuracy: 0.9615 - val_loss: 0.8454 - val_accuracy: 0.4615
# Epoch 114/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1344 - accuracy: 0.9615 - val_loss: 0.8448 - val_accuracy: 0.4615
# Epoch 115/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.2586 - accuracy: 0.9615 - val_loss: 0.6169 - val_accuracy: 0.6154
# Epoch 116/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.2305 - accuracy: 0.8846 - val_loss: 0.6021 - val_accuracy: 0.6154
# Epoch 117/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.3209 - accuracy: 0.8654 - val_loss: 0.6031 - val_accuracy: 0.6154
# Epoch 118/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.2127 - accuracy: 0.9231 - val_loss: 0.6259 - val_accuracy: 0.6154
# Epoch 119/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.2196 - accuracy: 0.9038 - val_loss: 0.6946 - val_accuracy: 0.5385
# Epoch 120/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.2213 - accuracy: 0.9615 - val_loss: 0.8478 - val_accuracy: 0.4615
# Epoch 121/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1635 - accuracy: 0.9615 - val_loss: 0.9835 - val_accuracy: 0.4615
# Epoch 122/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.2606 - accuracy: 0.9038 - val_loss: 1.0035 - val_accuracy: 0.4615
# Epoch 123/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.2713 - accuracy: 0.8654 - val_loss: 1.0214 - val_accuracy: 0.4615
# Epoch 124/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.2053 - accuracy: 0.9038 - val_loss: 1.0028 - val_accuracy: 0.4615
# Epoch 125/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1841 - accuracy: 0.9615 - val_loss: 1.0002 - val_accuracy: 0.4615
# Epoch 126/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.2066 - accuracy: 0.9231 - val_loss: 0.9534 - val_accuracy: 0.4615
# Epoch 127/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1605 - accuracy: 0.9423 - val_loss: 0.9104 - val_accuracy: 0.4615
# Epoch 128/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1530 - accuracy: 0.9615 - val_loss: 0.8632 - val_accuracy: 0.4615
# Epoch 129/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1465 - accuracy: 0.9808 - val_loss: 0.8467 - val_accuracy: 0.4615
# Epoch 130/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1706 - accuracy: 0.9615 - val_loss: 0.8554 - val_accuracy: 0.4615
# Epoch 131/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1592 - accuracy: 0.9615 - val_loss: 0.8681 - val_accuracy: 0.4615
# Epoch 132/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1612 - accuracy: 0.9615 - val_loss: 0.8583 - val_accuracy: 0.4615
# Epoch 133/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1680 - accuracy: 0.9808 - val_loss: 0.8688 - val_accuracy: 0.4615
# Epoch 134/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1393 - accuracy: 0.9615 - val_loss: 0.8845 - val_accuracy: 0.4615
# Epoch 135/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1318 - accuracy: 0.9615 - val_loss: 0.8897 - val_accuracy: 0.4615
# Epoch 136/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1744 - accuracy: 0.9038 - val_loss: 0.8858 - val_accuracy: 0.4615
# Epoch 137/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1482 - accuracy: 0.9808 - val_loss: 0.8757 - val_accuracy: 0.4615
# Epoch 138/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1874 - accuracy: 0.9231 - val_loss: 0.8610 - val_accuracy: 0.4615
# Epoch 139/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1396 - accuracy: 0.9615 - val_loss: 0.8661 - val_accuracy: 0.4615
# Epoch 140/150
# 2/2 [==============================] - 7s 3s/step - loss: 0.1656 - accuracy: 0.9423 - val_loss: 0.8644 - val_accuracy: 0.4615
# Epoch 141/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1357 - accuracy: 0.9423 - val_loss: 0.8508 - val_accuracy: 0.4615
# Epoch 142/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1551 - accuracy: 0.9615 - val_loss: 0.8327 - val_accuracy: 0.5385
# Epoch 143/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1177 - accuracy: 0.9808 - val_loss: 0.8047 - val_accuracy: 0.5385
# Epoch 144/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1453 - accuracy: 0.9231 - val_loss: 0.7833 - val_accuracy: 0.6154
# Epoch 145/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1312 - accuracy: 0.9808 - val_loss: 0.7816 - val_accuracy: 0.6154
# Epoch 146/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1364 - accuracy: 0.9808 - val_loss: 0.7978 - val_accuracy: 0.6154
# Epoch 147/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.2382 - accuracy: 0.9423 - val_loss: 0.8173 - val_accuracy: 0.5385
# Epoch 148/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1072 - accuracy: 0.9808 - val_loss: 0.8465 - val_accuracy: 0.4615
# Epoch 149/150
# 2/2 [==============================] - 6s 3s/step - loss: 0.1321 - accuracy: 0.9423 - val_loss: 0.8644 - val_accuracy: 0.4615
# Epoch 150/150
# 2/2 [==============================] - 7s 3s/step - loss: 0.1391 - accuracy: 0.9615 - val_loss: 0.8799 - val_accuracy: 0.4615

# %%
#TESTING MODEL JALANKAN KEEMPAT

# %%
df_test = pd.read_csv("/content/drive/MyDrive/dataset/test.csv")
TEST = "/content/drive/MyDrive/dataset/test/"

for index, row in tqdm(df_test.iterrows()):
    wave, sr = librosa.load(TEST + row["fname"], mono=True, sr=None)
    wave = wave[::2]
    
    stft = wav2stft(wave)
    X_test = stft.reshape(1, feature_dim_1, feature_dim_2, channel)
    preds = model.predict(X_test)[0]
    
    for i, col in enumerate(target_labels):
        df_test.loc[index, col] = preds[i]
# Out:
# 8it [00:02,  3.22it/s]

# %%
df_test
# Out:
#                         fname    labels  labels_count  target_labels_count  \
# 0  159_1b1_Al_sc_Meditron.wav    normal             1                    1
# 1  159_1b1_Ar_sc_Meditron.wav    normal             1                    1
# 2  159_1b1_Pr_sc_Meditron.wav    normal             1                    1
# 3  159_1b1_Ll_sc_Meditron.wav    normal             1                    1
# 4  161_1b1_Pl_sc_Meditron.wav  abnormal             0                    0
# 5  161_1b1_Al_sc_Meditron.wav  abnormal             0                    0
# 6  167_1b1_Al_sc_Meditron.wav  abnormal             0                    0
# 7  167_1b1_Pr_sc_Meditron.wav  abnormal             0                    0
#
#      normal  abnormal
# 0  0.997364  0.002636
# 1  0.884084  0.115916
# 2  0.471441  0.528559
# 3  0.991916  0.008084
# 4  0.009098  0.990902
# 5  0.472519  0.527481
# 6  0.516935  0.483065
# 7  0.761795  0.238205

# %%
preds
# Out:
# array([0.7617953 , 0.23820473], dtype=float32)

# %%
model.save('cnn_stft.h5')
